# %%
pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#                                               0.0/511.6 kB ? eta -:--:--
#      --                                       30.7/511.6 kB ? eta -:--:--
#      --------                               112.6/511.6 kB 1.7 MB/s eta 0:00:01
#      ------------                           174.1/511.6 kB 1.3 MB/s eta 0:00:01
#      -----------------                      235.5/511.6 kB 1.4 MB/s eta 0:00:01
#      ---------------------                  286.7/511.6 kB 1.5 MB/s eta 0:00:01
#      -------------------------------        430.1/511.6 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 511.6/511.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: ipython<9 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipympl) (8.14.0)
# Requirement already satisfied: numpy in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from ipympl) (1.24.3)
# Collecting ipython-genutils (from ipympl)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pillow in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from ipympl) (9.5.0)
# Requirement already satisfied: traitlets<6 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipympl) (5.9.0)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl)
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#                                               0.0/138.3 kB ? eta -:--:--
#      -------------------------------------- 138.3/138.3 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from ipympl) (3.7.1)
# Requirement already satisfied: backcall in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.6.2)
# Requirement already satisfied: colorama in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.23.1)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets<9,>=7.6.0->ipympl)
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      -                                        0.1/2.1 MB 3.2 MB/s eta 0:00:01
#      ---                                      0.2/2.1 MB 3.9 MB/s eta 0:00:01
#      ------                                   0.3/2.1 MB 3.5 MB/s eta 0:00:01
#      -------                                  0.4/2.1 MB 2.9 MB/s eta 0:00:01
#      ----------                               0.5/2.1 MB 2.8 MB/s eta 0:00:01
#      ------------                             0.7/2.1 MB 2.8 MB/s eta 0:00:01
#      -------------                            0.7/2.1 MB 2.8 MB/s eta 0:00:01
#      ------------------                       1.0/2.1 MB 2.9 MB/s eta 0:00:01
#      -------------------                      1.1/2.1 MB 2.9 MB/s eta 0:00:01
#      ------------------------                 1.3/2.1 MB 3.0 MB/s eta 0:00:01
#      ---------------------------              1.4/2.1 MB 3.1 MB/s eta 0:00:01
#      -----------------------------            1.6/2.1 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------       1.8/2.1 MB 3.2 MB/s eta 0:00:01
#      ------------------------------------     1.9/2.1 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 3.1 MB/s eta 0:00:00
# Collecting jupyterlab-widgets~=3.0.7 (from ipywidgets<9,>=7.6.0->ipympl)
#   Downloading jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
#                                               0.0/198.2 kB ? eta -:--:--
#      -------------------------------------- 198.2/198.2 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dngaj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: psutil in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (3.5.1)
# Requirement already satisfied: pywin32>=300 in c:\users\dngaj\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (306)
# Installing collected packages: ipython-genutils, widgetsnbextension, jupyterlab-widgets, ipywidgets, ipympl
# Successfully installed ipympl-0.9.3 ipython-genutils-0.2.0 ipywidgets-8.0.6 jupyterlab-widgets-3.0.7 widgetsnbextension-4.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone "https://github.com/Atharva-Malode/ML-Bootcamp"
# Out:
# Cloning into 'ML-Bootcamp'...

# %%
# !cp "/content/ML-Bootcamp/Week-1/Day-2/plots.py" "/content/"

# %%
import numpy as np 
import pandas as pd 
import os
import math
from sklearn.linear_model import SGDRegressor
import matplotlib.pyplot as plt
from ipywidgets import interact
from ipywidgets import interact

# %%
# %matplotlib widget
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
plt.style.use('./deeplearning.mplstyle')

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
# Generate random dataset
np.random.seed(42)
X = np.random.rand(100)
Y = 2 * X + 1 + np.random.randn(100) * 0.1

# Set initial parameter values
w_initial = 0
b_initial = 0

# Set hyperparameters
learning_rate = 0.01
num_iterations = 20000

# %%
# we used the 'marker' and 'c' parameters
plt.scatter(X,Y, marker='x', c='r') 

# Set the title
plt.title("Data Visualization")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# we used the 'marker' and 'c' parameters
plt.scatter(X,Y,c='r') 

# Set the title
plt.title("Data Visualization")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def compute_cost(x, y, w, b): 
    """
    Computes the cost function for linear regression.
    
    Args:
      x (ndarray (m,)): Data, m examples 
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters  
    
    Returns
        total_cost (float): The cost of using w,b as the parameters for linear regression
               to fit the data points in x and y
    """
    # number of training examples
    m = x.shape[0] 
    
    cost_sum = 0 
    for i in range(m): 
        f_wb = w * x[i] + b   
        cost = (f_wb - y[i]) ** 2  
        cost_sum = cost_sum + cost  
    total_cost = (1 / (2 * m)) * cost_sum  
    return total_cost

# %%
plt_intuition(X,Y)

# %%
plt.close('all') 
fig, ax, dyn_items = plt_stationary(X, Y)
updater = plt_update_onclick(fig, ax, X,Y,dyn_items)
