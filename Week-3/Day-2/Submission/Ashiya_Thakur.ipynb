# %%
# !git clone https://github.com/Atharva-Malode/ML-Bootcamp.git
# Out:
# Cloning into 'ML-Bootcamp'...
# remote: Enumerating objects: 450, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 450 (delta 59), reused 41 (delta 23), pack-reused 324
# Receiving objects: 100% (450/450), 9.74 MiB | 13.07 MiB/s, done.
# Resolving deltas: 100% (144/144), done.

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("/content/kimino .jpg")
img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
img = cv2.resize(img,(280,382))
img.shape
# Out:
# (382, 280, 3)

# %%
plt.imshow(img)
plt.show()

# %%
X = img.reshape((-1,3))
X
# Out:
# array([[ 92, 119, 162],
#        [ 92, 119, 162],
#        [ 92, 119, 162],
#        ...,
#        [ 32,  44,  56],
#        [ 32,  44,  56],
#        [ 33,  43,  53]], dtype=uint8)

# %%
X.shape
# Out:
# (106960, 3)

# %%
from sklearn.cluster import KMeans

# %%
k = 4
model = KMeans(n_clusters = k)
model.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
centroids = model.cluster_centers_
centroids
# Out:
# array([[ 98.61801496, 123.39424225, 164.10120058],
#        [ 41.36986556,  57.49560126,  79.36497119],
#        [ 69.56966921,  93.81824131, 124.52213232],
#        [ 23.69140858,  32.07498112,  42.46972528]])

# %%
import numpy as np

# %%
colors = np.array(centroids,dtype = 'uint8')
colors
# Out:
# array([[ 98, 123, 164],
#        [ 41,  57,  79],
#        [ 69,  93, 124],
#        [ 23,  32,  42]], dtype=uint8)

# %%
i = 1
for color in colors:
  plt.subplot(1,k,i)
  plt.axis("off")
  i = i + 1
  mat = np.zeros((100,100,3),dtype = 'uint8')
  mat[:,:,:] = color
  plt.imshow(mat)
plt.show()
