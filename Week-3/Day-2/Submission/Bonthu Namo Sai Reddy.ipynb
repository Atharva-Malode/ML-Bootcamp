# %%
# !git clone https://github.com/NsrBonthu/ML-Bootcamp.git
# Out:
# Cloning into 'ML-Bootcamp'...
# remote: Enumerating objects: 534, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 534 (delta 76), reused 71 (delta 32), pack-reused 366
# Receiving objects: 100% (534/534), 16.80 MiB | 21.56 MiB/s, done.
# Resolving deltas: 100% (175/175), done.

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("/content/testing K-clusters.jpeg")

img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
img = cv2.resize(img,(280,200))

img.shape
# Out:
# (200, 280, 3)

# %%
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = img.reshape((-1,3))
X.shape
# Out:
# (56000, 3)

# %%
from sklearn.cluster import KMeans

# %%
k = 4
model = KMeans(n_clusters = k)
model.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4)

# %%
centroids = model.cluster_centers_

# %%
centroids
# Out:
# array([[ 10.22970263,   8.72325675,  17.25413969],
#        [ 69.58697112, 130.7768077 , 193.80993956],
#        [180.76084041, 123.94434511, 121.18641037],
#        [ 40.18012013,  44.48070435,  70.20134946]])

# %%
import numpy as np

# %%
colors = np.array(centroids,dtype='uint8')

# %%
colors
# Out:
# array([[ 10,   8,  17],
#        [ 69, 130, 193],
#        [180, 123, 121],
#        [ 40,  44,  70]], dtype=uint8)

# %%
i = 1

for color in colors:
   plt.subplot(1,k,i)
   plt.axis("off")
   i = i + 1;
   mat = np.zeros((100,100,3),dtype='uint8')
   mat[:,:,:] = color
   plt.imshow(mat)
   plt.show
